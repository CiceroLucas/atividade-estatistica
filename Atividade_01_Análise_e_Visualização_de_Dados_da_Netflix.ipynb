# %% [markdown]
# A Netflix é um serviço de streaming baseado em assinatura que permite que nossos membros assistam a programas de TV e filmes em um dispositivo conectado à Internet. Nesse projeto iremos limpar, analisar e comparar dados da base Netflix utilizando a biblioteca Pandas do Python.
#
# Cicero Lucas Ferreira de Sousa

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Datasets/netflix_shows/netflix_dataset.csv')

# %%
df.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %% [markdown]
# # Algumas informações básicas da tabela

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Limpeza dos dados
#
# Nessa limpeza todos os dados duplicados foram tirados para garantir a veracidade dos dados

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace= True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# Para limparmos esses campos com valores nulos, utilizaremos a função dropna().

# %%
data_no_null = df.dropna().copy()
data_no_null
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data_no_null.isna().sum()
# Out:
# Show_Id         0
# Category        0
# Title           0
# Director        0
# Cast            0
# Country         0
# Release_Date    0
# Rating          0
# Duration        0
# Type            0
# Description     0
# dtype: int64

# %% [markdown]
# # Primeiras análises

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x=df['Category'])
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Análise dos filmes produzidos no Brasil

# %%
df[(df['Category'] == 'Movie') & (df['Country'] == 'Brazil')]['Title']
# Out:
# 208                                      A new Capitalism
# 320                             Afonso Padilha: Classless
# 394                                          Alice Junior
# 421                             All The Reasons To Forget
# 499                                         Ana e Vitória
# 674                                        Back and Forth
# 1066                                    Boy and the World
# 1126                                              Buddies
# 1294                            Chatô: The King of Brazil
# 1401                          City of God: 10 Years Later
# 1510                                   Couples Counseling
# 1786                                        DJ Cinderella
# 1832                                           Double Dad
# 1925    Edmilson Filho: Notas, Comedy about Relationships
# 1989            Emicida: AmarElo - It’s All For Yesterday
# 2144                  Felipe Neto: My Life Makes No Sense
# ...

# %%
df[(df['Category'] == 'Movie') & (df['Country'] == 'Brazil')]['Country'].value_counts()
# Out:
# Country
# Brazil    46
# Name: count, dtype: int64

# %% [markdown]
# ### Produções referente a todos os países

# %%
df['Country'].value_counts().head(15).plot.pie(title='País x Qtd. Produções')
# Out:
# <Axes: title={'center': 'País x Qtd. Produções'}, ylabel='count'>

# %% [markdown]
# ## Gráfico dos 20 que mais produziram

# %%
df['Director'].value_counts().head(20).plot.barh(title='Qtd. Produções x Diretor')
# Out:
# <Axes: title={'center': 'Qtd. Produções x Diretor'}, ylabel='Director'>

# %% [markdown]
# ## Categorização da Netflix

# %% [markdown]
# O sistema de categorização da Netflix permite agrupar mais de uma categoria para o mesmo filme, logo utilizaremos de duas formas para fazermos a análise.
# A primeira, vamos comparar com os dados aninhados, conforme a categorização netflix.

# %%
df['Type'].value_counts().head(5).plot.barh(title='Categoria x Qtd. Produções')
# Out:
# <Axes: title={'center': 'Categoria x Qtd. Produções'}, ylabel='Type'>

# %% [markdown]
# Para aquelas que tem duas categorias ou mais, apenas a primeira categoria, supondo ser a mais relevante.

# %%
first_data_type = df['Type'].str.split(',', expand=True)[0]
first_data_type.value_counts().head(5).plot.area(title='Categoria x Qtd. Produções', rot=10)
# Out:
# <Axes: title={'center': 'Categoria x Qtd. Produções'}, xlabel='0'>

# %% [markdown]
# ## Cálculo das estatísticas

# %%
movies_df = df[df['Category'] == 'Movie'].copy()

movies_df['Duration'] = movies_df['Duration'].str.replace(' min', '').astype(float)

# estatísticas descritivas da duração dos filmes
stats = movies_df['Duration'].describe()

# variância e desvio padrão
variance = movies_df['Duration'].var()
std_dev = movies_df['Duration'].std()

stats, variance, std_dev
# Out:
# (count    5377.000000
#  mean       99.307978
#  std        28.530881
#  min         3.000000
#  25%        86.000000
#  50%        98.000000
#  75%       114.000000
#  max       312.000000
#  Name: Duration, dtype: float64,
#  814.0111584310814,
#  28.53088078610756)

# %% [markdown]
# * Contagem: 5.379 filmes
#
# * Média: 99,31 minutos
#
# * Desvio Padrão: 28,53 minutos
#
# * Variância: 813,71 minutos²
#
# * Duração Mínima: 3 minutos
#
# * 1º Quartil (25%): 86 minutos
#
# * Mediana (50%): 98 minutos
#
# * 3º Quartil (75%): 114 minutos
#
# * Duração Máxima: 312 minutos
